# %%
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, f1_score, precision_score, recall_score
from tensorflow.keras.regularizers import l2

def load_data():
    (x_train, y_train), (x_test, y_test) = tfds.as_numpy(tfds.load(
        'kmnist', split=['train', 'test'], batch_size=-1, as_supervised=True
    ))
    x_train, x_test = x_train / 255.0, x_test / 255.0
    x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1, random_state=42)
    return x_train, x_val, x_test, y_train, y_val, y_test

def plot_sample_images(x_train, y_train):
    fig, axes = plt.subplots(2, 5, figsize=(10, 5))
    for i in range(10):
        ax = axes[i // 5, i % 5]
        idx = np.where(y_train == i)[0][0]
        ax.imshow(x_train[idx], cmap='gray')
        ax.set_title(str(i))
        ax.axis('off')
    plt.show()

def create_mlp(hidden_layers, activation, optimizer, weight_decay, learning_rate):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
    for units in hidden_layers:
        model.add(tf.keras.layers.Dense(units, activation=activation, kernel_regularizer=l2(weight_decay)))
    model.add(tf.keras.layers.Dense(10, activation='softmax'))
    optimizer = get_optimizer(optimizer, learning_rate)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

def get_optimizer(name, lr):
    if name in ['momentum', 'nesterov']:
        return tf.keras.optimizers.SGD(learning_rate=lr, momentum=0.9, nesterov=(name == 'nesterov'))
    return tf.keras.optimizers.get({'class_name': name, 'config': {'learning_rate': lr}})

def evaluate_model(model, x_test, y_test):
    y_pred = np.argmax(model.predict(x_test), axis=1)
    cm = confusion_matrix(y_test, y_pred)
    print(classification_report(y_test, y_pred))
    print("F1 Score:", f1_score(y_test, y_pred, average='weighted'))
    print("Precision:", precision_score(y_test, y_pred, average='weighted'))
    print("Recall:", recall_score(y_test, y_pred, average='weighted'))
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

def plot_training_history(history):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Accuracy Over Epochs')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Loss Over Epochs')
    plt.show()

x_train, x_val, x_test, y_train, y_val, y_test = load_data()
plot_sample_images(x_train, y_train)

hyperparameter_combinations = [
    (5, [128, 64], 'adam', 1e-3, 32, 'relu'),
    (10, [256, 128, 64], 'sgd', 1e-4, 64, 'sigmoid'),
    (15, [512, 256, 128], 'rmsprop', 1e-3, 32, 'relu'),
    (20, [128, 128], 'nesterov', 1e-4, 16, 'tanh')
]

best_val_acc = 0
best_model = None
results = []

for i, (num_epochs, hidden_layers, optimizer, learning_rate, batch_size, activation) in enumerate(hyperparameter_combinations):
    print(f"\nTraining Model {i+1}...")
    model = create_mlp(hidden_layers, activation, optimizer, 0.0005, learning_rate)
    history = model.fit(x_train, y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(x_val, y_val), verbose=1)
    val_loss, val_acc = model.evaluate(x_val, y_val, verbose=0)
    test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_model = model
    results.append({'Model': i+1, 'Validation Accuracy': val_acc, 'Test Accuracy': test_acc})
    plot_training_history(history)

df_results = pd.DataFrame(results)
display(df_results)

evaluate_model(best_model, x_test, y_test)
# Out:
# Downloading and preparing dataset 20.26 MiB (download: 20.26 MiB, generated: 31.76 MiB, total: 52.02 MiB) to /root/tensorflow_datasets/kmnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/kmnist/incomplete.XF8H84_3.0.1/kmnist-train.tfrecord*...:   0%|          |…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/kmnist/incomplete.XF8H84_3.0.1/kmnist-test.tfrecord*...:   0%|          | …
# Dataset kmnist downloaded and prepared to /root/tensorflow_datasets/kmnist/3.0.1. Subsequent calls will reuse this data.
# Training Model 1...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8071 - loss: 0.7811 - val_accuracy: 0.9267 - val_loss: 0.3837
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9354 - loss: 0.3555 - val_accuracy: 0.9395 - val_loss: 0.3331
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9521 - loss: 0.2969 - val_accuracy: 0.9415 - val_loss: 0.3198
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9580 - loss: 0.2741 - val_accuracy: 0.9435 - val_loss: 0.3049
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9600 - loss: 0.2577 - val_accuracy: 0.9457 - val_loss: 0.2976
# Training Model 2...
# Epoch 1/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.0981 - loss: 2.8951 - val_accuracy: 0.1025 - val_loss: 2.8179
# Epoch 2/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0999 - loss: 2.8059 - val_accuracy: 0.1035 - val_loss: 2.7537
# Epoch 3/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0954 - loss: 2.7488 - val_accuracy: 0.0928 - val_loss: 2.7108
# Epoch 4/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0882 - loss: 2.7080 - val_accuracy: 0.0965 - val_loss: 2.6819
# Epoch 5/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0917 - loss: 2.6803 - val_accuracy: 0.1013 - val_loss: 2.6622
# Epoch 6/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0977 - loss: 2.6618 - val_accuracy: 0.1023 - val_loss: 2.6489
# Epoch 7/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0989 - loss: 2.6487 - val_accuracy: 0.1027 - val_loss: 2.6398
# Epoch 8/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0986 - loss: 2.6393 - val_accuracy: 0.1028 - val_loss: 2.6336
# Epoch 9/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0974 - loss: 2.6343 - val_accuracy: 0.1027 - val_loss: 2.6294
# Epoch 10/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0978 - loss: 2.6291 - val_accuracy: 0.1023 - val_loss: 2.6264
# Training Model 3...
# Epoch 1/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8287 - loss: 0.9451 - val_accuracy: 0.9037 - val_loss: 0.5084
# Epoch 2/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9355 - loss: 0.3917 - val_accuracy: 0.9417 - val_loss: 0.3406
# Epoch 3/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9444 - loss: 0.3174 - val_accuracy: 0.9492 - val_loss: 0.2900
# Epoch 4/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9521 - loss: 0.2776 - val_accuracy: 0.9347 - val_loss: 0.3438
# Epoch 5/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9559 - loss: 0.2571 - val_accuracy: 0.9345 - val_loss: 0.3348
# Epoch 6/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9582 - loss: 0.2398 - val_accuracy: 0.9368 - val_loss: 0.3231
# Epoch 7/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9598 - loss: 0.2306 - val_accuracy: 0.9397 - val_loss: 0.3007
# Epoch 8/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9615 - loss: 0.2203 - val_accuracy: 0.9543 - val_loss: 0.2513
# Epoch 9/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9631 - loss: 0.2172 - val_accuracy: 0.9372 - val_loss: 0.2948
# Epoch 10/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9642 - loss: 0.2081 - val_accuracy: 0.9452 - val_loss: 0.2655
# Epoch 11/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9653 - loss: 0.2003 - val_accuracy: 0.9372 - val_loss: 0.2987
# Epoch 12/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9635 - loss: 0.2086 - val_accuracy: 0.9330 - val_loss: 0.3182
# Epoch 13/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9646 - loss: 0.2029 - val_accuracy: 0.9478 - val_loss: 0.2579
# Epoch 14/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9665 - loss: 0.1964 - val_accuracy: 0.9507 - val_loss: 0.2545
# Epoch 15/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9653 - loss: 0.1976 - val_accuracy: 0.9407 - val_loss: 0.2797
# Training Model 4...
# Epoch 1/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.4361 - loss: 1.9455 - val_accuracy: 0.7297 - val_loss: 1.1771
# Epoch 2/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7349 - loss: 1.1183 - val_accuracy: 0.7758 - val_loss: 0.9654
# Epoch 3/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7790 - loss: 0.9386 - val_accuracy: 0.7940 - val_loss: 0.8785
# Epoch 4/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7944 - loss: 0.8738 - val_accuracy: 0.8055 - val_loss: 0.8274
# Epoch 5/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8061 - loss: 0.8207 - val_accuracy: 0.8168 - val_loss: 0.7919
# Epoch 6/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8156 - loss: 0.7880 - val_accuracy: 0.8223 - val_loss: 0.7639
# Epoch 7/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8253 - loss: 0.7564 - val_accuracy: 0.8290 - val_loss: 0.7401
# Epoch 8/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8344 - loss: 0.7264 - val_accuracy: 0.8368 - val_loss: 0.7217
# Epoch 9/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8420 - loss: 0.7085 - val_accuracy: 0.8405 - val_loss: 0.7020
# Epoch 10/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8475 - loss: 0.6836 - val_accuracy: 0.8477 - val_loss: 0.6854
# Epoch 11/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8488 - loss: 0.6790 - val_accuracy: 0.8505 - val_loss: 0.6698
# Epoch 12/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8547 - loss: 0.6620 - val_accuracy: 0.8553 - val_loss: 0.6540
# Epoch 13/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8636 - loss: 0.6374 - val_accuracy: 0.8612 - val_loss: 0.6399
# Epoch 14/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8635 - loss: 0.6313 - val_accuracy: 0.8660 - val_loss: 0.6263
# Epoch 15/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8701 - loss: 0.6102 - val_accuracy: 0.8673 - val_loss: 0.6135
# Epoch 16/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8725 - loss: 0.6020 - val_accuracy: 0.8712 - val_loss: 0.6022
# Epoch 17/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8766 - loss: 0.5873 - val_accuracy: 0.8745 - val_loss: 0.5905
# Epoch 18/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8818 - loss: 0.5706 - val_accuracy: 0.8783 - val_loss: 0.5802
# Epoch 19/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8836 - loss: 0.5637 - val_accuracy: 0.8818 - val_loss: 0.5701
# Epoch 20/20
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8837 - loss: 0.5547 - val_accuracy: 0.8815 - val_loss: 0.5603
#    Model  Validation Accuracy  Test Accuracy
# 0      1             0.945667         0.8828
# 1      2             0.102333         0.0991
# 2      3             0.940667         0.8783
# 3      4             0.881500         0.7712
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.87      0.91      1000
#            1       0.81      0.88      0.84      1000
#            2       0.91      0.80      0.85      1000
#            3       0.84      0.96      0.89      1000
#            4       0.89      0.83      0.86      1000
#            5       0.94      0.91      0.92      1000
#            6       0.83      0.94      0.88      1000
#            7       0.93      0.88      0.91      1000
#            8       0.87      0.86      0.87      1000
#            9       0.90      0.90      0.90      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.89      0.88      0.88     10000
# weighted avg       0.89      0.88      0.88     10000
#
# F1 Score: 0.8828436769210448
# Precision: 0.8859785669693537
# Recall: 0.8828
